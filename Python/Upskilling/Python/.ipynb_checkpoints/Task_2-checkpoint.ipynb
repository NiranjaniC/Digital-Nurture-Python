# %% [markdown]
# ## My First Jupyter Notebook
# Created as part of Cognizant DN5.0 upskilling program.
#
# ## Jupyter Notebook
# • Objective: Create Jupyter notebook.
#
# • Task: Basic notebook operations.

# %%
num1 = 10
num2 = 20
print(f"Sum: {num1+num2}")
print(f"Product: {num1*num2}")
# Out:
# Sum: 30
# Product: 200
